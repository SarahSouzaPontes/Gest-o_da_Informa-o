# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahSouzaPontes/Gest-o_da_Informa-o/blob/main/Gest%C3%A3o_da_Informa%C3%A7%C3%A3o_06_03_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Parametrização </h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>Documentação</h2>

# %%
#COLUNAS PLANILHA ESTÁCIO DIGITAL
print("SKU\nCHAVE\nCOD_CAMPUS_PAI\nCOD_CAMPUS\nCOD_CURSO_PAI\nCOD_CURSO\nCOD_TURNO\nCOD_HABILITACAO\nMODALIDADE\nCAPTACAO\nUF\nMUNICIPIO\nCOD_IES\nNOME_IES\nNOME_CAMPUS\nNOME_CURSO\nTURNO\nGRAU_ACADEMICO\nTIPO_CURSO\nQTD_MIN_PERIODO\nQTD_MAX_PERIODO\nAREA_CONHECIMENTO\nIES_GRUPO\nTIPO_POLO\nISENCAO\nESTOQUE\nFLAG_BOLSA_REGRESSIVA\nPRECO_CHEIO\nOFERTA_ESTACIO\nOFERTA_PARCEIRO\nDESCONTO_PARCEIRO_ONLINE\nPRECO_POR_PARCEIRO_ONLINE\nBOLSA_REGRESSIVA_PARCEIRO\nPREÇO_REGRESSIVO_PARCEIRO_ONLINE\nENDEREÇO_POLO\nDATA_ATUALIZACAO")
# Out:
# SKU
# CHAVE
# COD_CAMPUS_PAI
# COD_CAMPUS
# COD_CURSO_PAI
# COD_CURSO
# COD_TURNO
# COD_HABILITACAO
# MODALIDADE
# CAPTACAO
# UF
# MUNICIPIO
# COD_IES
# NOME_IES
# NOME_CAMPUS
# NOME_CURSO
# TURNO
# GRAU_ACADEMICO
# TIPO_CURSO
# QTD_MIN_PERIODO
# QTD_MAX_PERIODO
# AREA_CONHECIMENTO
# IES_GRUPO
# TIPO_POLO
# ISENCAO
# ESTOQUE
# FLAG_BOLSA_REGRESSIVA
# PRECO_CHEIO
# OFERTA_ESTACIO
# OFERTA_PARCEIRO
# DESCONTO_PARCEIRO_ONLINE
# PRECO_POR_PARCEIRO_ONLINE
# BOLSA_REGRESSIVA_PARCEIRO
# PREÇO_REGRESSIVO_PARCEIRO_ONLINE
# ENDEREÇO_POLO
# DATA_ATUALIZACAO

# %%
#COLUNAS ESTÁCIO PRESENCIAL
print("SKU\tCHAVE\tCOD_CAMPUS_PAI\tCOD_CAMPUS\tCOD_CURSO_PAI\tCOD_CURSO\tCOD_TURNO\tCOD_HABILITACAO\tMODALIDADE\tCAPTACAO\tUF\tMUNICIPIO\tCOD_IES\tNOME_IES\tNOME_CAMPUS\tNOME_CURSO\tTURNO\tGRAU_ACADEMICO\tTIPO_CURSO\tQTD_MIN_PERIODO\tQTD_MAX_PERIODO\tAREA_CONHECIMENTO\tIES_GRUPO\tTIPO_POLO\tISENCAO\tESTOQUE\tFLAG_BOLSA_REGRESSIVA\tPRECO_CHEIO\tOFERTA_ESTACIO\tOFERTA_PARCEIRO\tDESCONTO_PARCEIRO_ONLINE\tPRECO_POR_PARCEIRO_ONLINE\tBOLSA_REGRESSIVA_PARCEIRO\tPREÇO_REGRESSIVO_PARCEIRO_ONLINE\tENDEREÇO_POLO\tDATA_ATUALIZAÇÃO")
# Out:
# SKU	CHAVE	COD_CAMPUS_PAI	COD_CAMPUS	COD_CURSO_PAI	COD_CURSO	COD_TURNO	COD_HABILITACAO	MODALIDADE	CAPTACAO	UF	MUNICIPIO	COD_IES	NOME_IES	NOME_CAMPUS	NOME_CURSO	TURNO	GRAU_ACADEMICO	TIPO_CURSO	QTD_MIN_PERIODO	QTD_MAX_PERIODO	AREA_CONHECIMENTO	IES_GRUPO	TIPO_POLO	ISENCAO	ESTOQUE	FLAG_BOLSA_REGRESSIVA	PRECO_CHEIO	OFERTA_ESTACIO	OFERTA_PARCEIRO	DESCONTO_PARCEIRO_ONLINE	PRECO_POR_PARCEIRO_ONLINE	BOLSA_REGRESSIVA_PARCEIRO	PREÇO_REGRESSIVO_PARCEIRO_ONLINE	ENDEREÇO_POLO	DATA_ATUALIZAÇÃO

# %%
#COLUNAS PLANILHA MODELO GALENA
print("catalog_hide\
tcursos_horários.id\
tChaveamento (external_id)\
tCurso (título do card)\
tInformação Complementar (Subtítulo do card)\
tDescrição do curso (HTML)\tDuração do Curso\
tDuração-tipo\
tÉ mensalidade?\
tParcelas\
tValor da mensalidade/Valor total do curso\
tDesconto exclusivo Edupass (%)\tCategoria\
tCategoria específica\
tTipo\
tCampus/Polo/Unidade/Online\
tEndereço\
tBairro\
tCidade\
tUF\
tModalidade\
tTurno")
# Out:
# catalog_hidetcursos_horários.idtChaveamento (external_id)tCurso (título do card)tInformação Complementar (Subtítulo do card)tDescrição do curso (HTML)	Duração do CursotDuração-tipotÉ mensalidade?tParcelastValor da mensalidade/Valor total do cursotDesconto exclusivo Edupass (%)	CategoriatCategoria específicatTipotCampus/Polo/Unidade/OnlinetEndereçotBairrotCidadetUFtModalidadetTurno

# %%
import pandas as pd
from google.colab import drive

# %%
# Especificar o caminho para o arquivo Excel no Google Drive
caminho_arquivo_excel = '/content/sample_data/galena.xlsx'



# Ler apenas a aba 1 do arquivo Excel
dados_aba1 = pd.read_excel(caminho_arquivo_excel, sheet_name='Como preencher a planilha de at')

# Imprimir os dados da aba 1
print("Dados da aba 1 (dataset1):")
print(dados_aba1)
print("\n")
# Out:
# Dados da aba 1 (dataset1):
#                                           Unnamed: 0  \
# 0  **Disclaimer \nUtilize a explicação ao lado pa...
# 1                                                NaN
# 2  Obs: Na aba "Preencha os novos preços aqui" es...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                               Coluna  \
# 0        catalog_hide\n(preencher sempre como falso)
# 1                cursos_horarios.id\n(não preencher)
# 2                          Chaveamento (external_id)
# 3              Curso (título do card)\n(obrigatório)
# 4  Informação Complementar (Subtítulo do card)\n(...
# 5              Descrição do curso (HTML)\n(opcional)
# 6                    Duração do curso\n(obrigatório)
# 7                        Duração-tipo\n(obrigatório)
#
#                             O que precisa preencher?  \
# 0  Verdadeiro: Não aparece no catálogo nem na pes...
# 1  Esse é o ID do card. \n\nSe for feito um uploa...
# 2  Este campo serve para  criar um ID customizado...
# 3                      Preencher com o nome do curso
# 4  Este campo é opcional e o seu preenchimento é ...
# 5  Este campo é a descrição do curso que irá apar...
# 6  Preencher com o número inteiro da duração do c...
# 7  Preencher com o tipo de duração do número da c...
#
#                                             Coluna.1  \
# 0                     É mensalidade? \n(obrigatório)
# 1                           Parcelas \n(obrigatório)
# 2  Valor da mensalidade/Valor total do curso\n(ob...
# 3      Desconto exclusivo Edupass (%)\n(obrigatório)
# 4                           Categoria\n(obrigatório)
# 5  Categoria específica\n(obrigatório para gradua...
# 6         Campus/Polo/Unidade/Online \n(obrigatório)
# 7                               Endereço\n(opcional)
#
#                           O que precisa preencher?.1  \
# 0  Preencher da seguinte forma:\nSim = "Valor da ...
# 1  Este campo é utilizado para calcular o valor t...
# 2  Preencher o valor do curso (sem o desconto Edu...
# 3  Colocar o percentual de desconto. É importante...
# 4  Preencher com a categoria de qual o curso pert...
# 5  Preencher de acordo com a especificação do cur...
# 6  Este campo é obrigatório ser preenchido. Aqui ...
# 7               Inserir o endereço do pólo do curso.
#
#                     Coluna.2  \
# 0         Bairro\n(opcional)
# 1      Cidade\n(obrigatório)
# 2          UF\n(obrigatório)
# 3  Modalidade\n(obrigatório)
# 4       Turno\n(obrigatório)
# 5                        NaN
# 6                        NaN
# 7                        NaN
#
#                           O que precisa preencher?.2
# 0                           Inserir o bairro do pólo
# 1                           Inserir a cidade do pólo
# 2                               Inserir o UF do pólo
# 3  Preencher conforme as opções do dropdown da pl...
# 4  Preencher conforme as opções do dropdown da pl...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN

# %%
# Ler apenas a aba 2 do arquivo Excel
dados_aba2 = pd.read_excel(caminho_arquivo_excel, sheet_name='Preencha os novos preços aqui')

# Imprimir os dados da aba 2
print("Dados da aba 2 (dataset2):")
print(dados_aba2)
print("\n")

#Unir os datasets Estacio Presencial e Digital
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-437ffc1b4450> in <cell line: 2>()
#       1 # Ler apenas a aba 2 do arquivo Excel
# ----> 2 dados_aba2 = pd.read_excel(caminho_arquivo_excel, sheet_name='Preencha os novos preços aqui')
#       3
#       4 # Imprimir os dados da aba 2
#       5 print("Dados da aba 2 (dataset2):")
#
# NameError: name 'caminho_arquivo_excel' is not defined

# %%
import pandas as pd

# Especificar o caminho para o primeiro arquivo Excel no Google Drive
caminho_arquivo1 = '/content/sample_data/Anima.xlsx'

# Especificar o caminho para o segundo arquivo Excel no Google Drive
#caminho_arquivo2 = '/content/sample_data/EstacioD.xlsx'

# Ler ambos os arquivos Excel como conjuntos de dados (datasets)
dataset_estacio = pd.read_excel(caminho_arquivo1)
#dataset_estacio2 = pd.read_excel(caminho_arquivo2)

# Unir os conjuntos de dados
#dataset_estacio= pd.concat([dataset_estacio1, dataset_estacio2])

# Verificar as primeiras linhas do conjunto de dados unido para garantir que a união foi feita corretamente
print(dataset_estacio.head())
# Out:
#     CHAVE GERAL  IES                           POLO FUNÇÃO DO POLO  \
# 0  UAM-1055-102  UAM                 ITAIM PAULISTA    POLO FÍSICO
# 1  UAM-1077-102  UAM         SÃO PAULO - ARICANDUVA    POLO FÍSICO
# 2   UAM-877-102  UAM        SÃO PAULO - BARRA FUNDA    POLO FÍSICO
# 3  UAM-1073-102  UAM            SÃO PAULO - BUTANTÃ    POLO FÍSICO
# 4  UAM-1146-102  UAM  SÃO PAULO - CIDADE TIRADENTES    POLO FÍSICO
#
#   MICRORREGIÃO     CIDADE CID SEM ACENTO  UF DEGREE  GRAU             ÁREA  \
# 0    São Paulo  SÃO PAULO      SAO PAULO  SP   GRAD  BACH  TI & COMPUTAÇÃO
# 1    São Paulo  SÃO PAULO      SAO PAULO  SP   GRAD  BACH  TI & COMPUTAÇÃO
# 2    São Paulo  SÃO PAULO      SAO PAULO  SP   GRAD  BACH  TI & COMPUTAÇÃO
# 3    São Paulo  SÃO PAULO      SAO PAULO  SP   GRAD  BACH  TI & COMPUTAÇÃO
# 4    São Paulo  SÃO PAULO      SAO PAULO  SP   GRAD  BACH  TI & COMPUTAÇÃO
#
#                                   CURSO  PARCELAS VALOR CHEIO  BOLSA  VALOR  \
# 0  BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO        48         598   0.55  269.1
# 1  BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO        48         598   0.55  269.1
# 2  BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO        48         598   0.55  269.1
# 3  BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO        48         598   0.55  269.1
# 4  BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO        48         598   0.55  269.1
#
#   ALTERAÇÕES V2
# 0             -
# 1             -
# 2             -
# 3             -
# 4             -

# %%
# Definindo o dicionário de dados para dataset_galena


dados_galena = {
    "catalog_hide": "Falso",
#catalog_hide
#Verdadeiro
#Falso
#Todos são falsos até que seja sinalizado algum verdadeiro.

    "cursos_horários.id": dataset_estacio['CHAVE GERAL'],
    "Chaveamento (external_id)": "",
    "Curso (título do card)": dataset_estacio['CURSO'].apply(lambda x: x.title()),
    "Informação Complementar (Subtítulo do card)": "",
    "Descrição do curso (HTML)": "",
    "Duração do Curso": dataset_estacio['PARCELAS'],
    "Duração-tipo": "Hora",
    "É mensalidade?": "Sim",
#É mensalidade?
#Sim
#Não
#Cursos da estácio são sempre mensalidade. Ou seja, sempre "sim".

    "Parcelas": dataset_estacio['PARCELAS'],
    "Valor da mensalidade/Valor total do curso": dataset_estacio['VALOR CHEIO'],
    "Desconto exclusivo Edupass (%)": dataset_estacio['BOLSA'].map(lambda x: f"{x:.2f}%"),
    "Categoria": dataset_estacio['DEGREE'].apply(lambda x: x.title()),

#Categoria
#Cuta Duração
#Cursos Técnicos
#Desenvolvimento Pessoal
#Ensino Básico
#Graduação
#Idiomas
#Pé-Vetsibular
#Pós Graduação
#Para crianças e adolescentes
#Tech & Digital
# Etácio - Sempre Graduação.

    "Categoria específica": dataset_estacio['DEGREE'].apply(lambda x: x.title()),
#Categoria Específicas
#Bacharelado
#Doutorado
#Mestrado
#Especialização
#Licenciatura
#MBA
#Tecnologia
# Na estácio Categoria Específica é = a Grau Acadêmico. Manter primeira maíuscula e reduzir a caixa alta das demais letras para a versão final

    "Tipo": dataset_estacio['DEGREE'].apply(lambda x: x.title()),

#Tipo
#Livre
#Pós Graduação
#Graduação
#Técnico
#Idiomas
#Básico
#Na Estácio será sempre igual a Coluna da "Categoria" do padrão da Galena.

    "Campus/Polo/Unidade/Online": dataset_estacio['POLO'].apply(lambda x: x.title()),
    "Endereço": dataset_estacio['MICRORREGIÃO'].apply(lambda x: x.title() if isinstance(x, str) else x),
    "Bairro": "",
    "Cidade": dataset_estacio['CIDADE'].apply(lambda x: x.title()),
    "UF": dataset_estacio['UF'],
    "Modalidade": 'Graduação',
    "Turno": 'Flexível',
#Turno
#Manhã
#Tarde
#Noite
#Flexível
#Integral
#Correspondência da coluna "TURNO", porém deixar a primeira maiúscila e demais caixa baixa.
#Quando tiver mais de um turno na mesma coluna pode substituir por "Flexível".
#Quando o Turno apresentar o valor "Virtual" Substituir por "Flexével"

    "FLAG_BOLSA_REGRESSIVA": dataset_estacio['BOLSA'],
    "BOLSA_REGRESSIVA_PARCEIRO" :  dataset_estacio['BOLSA'].map(lambda x: '{:.2%}'.format(x))
 #   "NOME_IES" : dataset_estacio["NOME_IES"]

}

# Criar o dataset_galena a partir do dicionário de dados
dataset_galena = pd.DataFrame(dados_galena)

# %%
dataset_galena
# Out:
#       catalog_hide cursos_horários.id Chaveamento (external_id)  \
# 0            Falso       UAM-1055-102
# 1            Falso       UAM-1077-102
# 2            Falso        UAM-877-102
# 3            Falso       UAM-1073-102
# 4            Falso       UAM-1146-102
# ...            ...                ...                       ...
# 47052        Falso         UNA-190-51
# 47053        Falso         UNA-190-52
# 47054        Falso          UNA-190-5
# 47055        Falso          UNA-190-8
# 47056        Falso         UNA-190-11
#
#                                   Curso (título do card)  \
# 0                   Bacharelado Em Ciência Da Computação
# 1                   Bacharelado Em Ciência Da Computação
# 2                   Bacharelado Em Ciência Da Computação
# 3                   Bacharelado Em Ciência Da Computação
# 4                   Bacharelado Em Ciência Da Computação
# ...                                                  ...
# 47052  Curso Superior De Tecnologia Em Design De Inte...
# 47053     Curso Superior De Tecnologia Em Design Gráfico
# 47054  Curso Superior De Tecnologia Em Gestão De Recu...
# 47055     Curso Superior De Tecnologia Em Gestão Pública
# 47056          Curso Superior De Tecnologia Em Logística
#
#       Informação Complementar (Subtítulo do card) Descrição do curso (HTML)  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...                       ...
# 47052
# 47053
# 47054
# 47055
# 47056
#
#        Duração do Curso Duração-tipo É mensalidade?  Parcelas  ...  Tipo  \
# 0                    48         Hora            Sim        48  ...  Grad
# 1                    48         Hora            Sim        48  ...  Grad
# 2                    48         Hora            Sim        48  ...  Grad
# 3                    48         Hora            Sim        48  ...  Grad
# 4                    48         Hora            Sim        48  ...  Grad
# ...                 ...          ...            ...       ...  ...   ...
# 47052                24         Hora            Sim        24  ...  Grad
# 47053                24         Hora            Sim        24  ...  Grad
# 47054                24         Hora            Sim        24  ...  Grad
# 47055                24         Hora            Sim        24  ...  Grad
# 47056                24         Hora            Sim        24  ...  Grad
#
#            Campus/Polo/Unidade/Online        Endereço Bairro          Cidade  \
# 0                      Itaim Paulista       São Paulo              São Paulo
# 1              São Paulo - Aricanduva       São Paulo              São Paulo
# 2             São Paulo - Barra Funda       São Paulo              São Paulo
# 3                 São Paulo - Butantã       São Paulo              São Paulo
# 4       São Paulo - Cidade Tiradentes       São Paulo              São Paulo
# ...                               ...             ...    ...             ...
# 47052  Belo Horizonte - Santo Antônio  Belo Horizonte         Belo Horizonte
# 47053  Belo Horizonte - Santo Antônio  Belo Horizonte         Belo Horizonte
# 47054  Belo Horizonte - Santo Antônio  Belo Horizonte         Belo Horizonte
# 47055  Belo Horizonte - Santo Antônio  Belo Horizonte         Belo Horizonte
# 47056  Belo Horizonte - Santo Antônio  Belo Horizonte         Belo Horizonte
#
#        UF Modalidade     Turno FLAG_BOLSA_REGRESSIVA BOLSA_REGRESSIVA_PARCEIRO
# 0      SP  Graduação  Flexível                  0.55                    55.00%
# 1      SP  Graduação  Flexível                  0.55                    55.00%
# 2      SP  Graduação  Flexível                  0.55                    55.00%
# 3      SP  Graduação  Flexível                  0.55                    55.00%
# 4      SP  Graduação  Flexível                  0.55                    55.00%
# ...    ..        ...       ...                   ...                       ...
# 47052  MG  Graduação  Flexível                  0.60                    60.00%
# 47053  MG  Graduação  Flexível                  0.60                    60.00%
# 47054  MG  Graduação  Flexível                  0.60                    60.00%
# 47055  MG  Graduação  Flexível                  0.60                    60.00%
# 47056  MG  Graduação  Flexível                  0.60                    60.00%
#
# [47057 rows x 24 columns]

# %%
distinct_values = dataset_galena['Tipo'].unique()

print(distinct_values)
# Out:
# ['Grad']

# %%
# Assuming dataset_galena is your DataFrame
dataset_galena['Tipo'] = dataset_galena['Tipo'].replace('Grad', 'Graduação')
# Assuming dataset_galena is your DataFrame
dataset_galena['Categoria'] = dataset_galena['Tipo'].replace('Grad', 'Graduação')
# Assuming dataset_galena is your DataFrame
dataset_galena['Categoria específica'] = dataset_galena['Tipo'].replace('Grad', 'Graduação')

# %%
# Assuming dataset_galena is your DataFrame
columns_list = dataset_galena.columns.tolist()

print(columns_list)
# Out:
# ['catalog_hide', 'cursos_horários.id', 'Chaveamento (external_id)', 'Curso (título do card)', 'Informação Complementar (Subtítulo do card)', 'Descrição do curso (HTML)', 'Duração do Curso', 'Duração-tipo', 'É mensalidade?', 'Parcelas', 'Valor da mensalidade/Valor total do curso', 'Desconto exclusivo Edupass (%)', 'Categoria', 'Categoria específica', 'Tipo', 'Campus/Polo/Unidade/Online', 'Endereço', 'Bairro', 'Cidade', 'UF', 'Modalidade', 'Turno', 'FLAG_BOLSA_REGRESSIVA', 'BOLSA_REGRESSIVA_PARCEIRO']

# %%
dataset_galena = dataset_galena.drop(columns=['FLAG_BOLSA_REGRESSIVA', 'BOLSA_REGRESSIVA_PARCEIRO'])

# %%
dataset_galena
# Out:
#       catalog_hide cursos_horários.id Chaveamento (external_id)  \
# 0            Falso       UAM-1055-102
# 1            Falso       UAM-1077-102
# 2            Falso        UAM-877-102
# 3            Falso       UAM-1073-102
# 4            Falso       UAM-1146-102
# ...            ...                ...                       ...
# 47052        Falso         UNA-190-51
# 47053        Falso         UNA-190-52
# 47054        Falso          UNA-190-5
# 47055        Falso          UNA-190-8
# 47056        Falso         UNA-190-11
#
#                                   Curso (título do card)  \
# 0                   Bacharelado Em Ciência Da Computação
# 1                   Bacharelado Em Ciência Da Computação
# 2                   Bacharelado Em Ciência Da Computação
# 3                   Bacharelado Em Ciência Da Computação
# 4                   Bacharelado Em Ciência Da Computação
# ...                                                  ...
# 47052  Curso Superior De Tecnologia Em Design De Inte...
# 47053     Curso Superior De Tecnologia Em Design Gráfico
# 47054  Curso Superior De Tecnologia Em Gestão De Recu...
# 47055     Curso Superior De Tecnologia Em Gestão Pública
# 47056          Curso Superior De Tecnologia Em Logística
#
#       Informação Complementar (Subtítulo do card) Descrição do curso (HTML)  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...                       ...
# 47052
# 47053
# 47054
# 47055
# 47056
#
#        Duração do Curso Duração-tipo É mensalidade?  Parcelas  ...  \
# 0                    48         Hora            Sim        48  ...
# 1                    48         Hora            Sim        48  ...
# 2                    48         Hora            Sim        48  ...
# 3                    48         Hora            Sim        48  ...
# 4                    48         Hora            Sim        48  ...
# ...                 ...          ...            ...       ...  ...
# 47052                24         Hora            Sim        24  ...
# 47053                24         Hora            Sim        24  ...
# 47054                24         Hora            Sim        24  ...
# 47055                24         Hora            Sim        24  ...
# 47056                24         Hora            Sim        24  ...
#
#       Categoria específica       Tipo      Campus/Polo/Unidade/Online  \
# 0                Graduação  Graduação                  Itaim Paulista
# 1                Graduação  Graduação          São Paulo - Aricanduva
# 2                Graduação  Graduação         São Paulo - Barra Funda
# 3                Graduação  Graduação             São Paulo - Butantã
# 4                Graduação  Graduação   São Paulo - Cidade Tiradentes
# ...                    ...        ...                             ...
# 47052            Graduação  Graduação  Belo Horizonte - Santo Antônio
# 47053            Graduação  Graduação  Belo Horizonte - Santo Antônio
# 47054            Graduação  Graduação  Belo Horizonte - Santo Antônio
# 47055            Graduação  Graduação  Belo Horizonte - Santo Antônio
# 47056            Graduação  Graduação  Belo Horizonte - Santo Antônio
#
#              Endereço Bairro          Cidade  UF Modalidade     Turno  \
# 0           São Paulo              São Paulo  SP  Graduação  Flexível
# 1           São Paulo              São Paulo  SP  Graduação  Flexível
# 2           São Paulo              São Paulo  SP  Graduação  Flexível
# 3           São Paulo              São Paulo  SP  Graduação  Flexível
# 4           São Paulo              São Paulo  SP  Graduação  Flexível
# ...               ...    ...             ...  ..        ...       ...
# 47052  Belo Horizonte         Belo Horizonte  MG  Graduação  Flexível
# 47053  Belo Horizonte         Belo Horizonte  MG  Graduação  Flexível
# 47054  Belo Horizonte         Belo Horizonte  MG  Graduação  Flexível
# 47055  Belo Horizonte         Belo Horizonte  MG  Graduação  Flexível
# 47056  Belo Horizonte         Belo Horizonte  MG  Graduação  Flexível
#
#       Categoria Específica
# 0                Graduação
# 1                Graduação
# 2                Graduação
# 3                Graduação
# 4                Graduação
# ...                    ...
# 47052            Graduação
# 47053            Graduação
# 47054            Graduação
# 47055            Graduação
# 47056            Graduação
#
# [47057 rows x 23 columns]

# %%
# Especificar o caminho para salvar o arquivo Excel
caminho_salvar = '/content/sample_data/dataset_galena_estacio.xlsx'

# Salvar o DataFrame dataset_galena em um arquivo Excel
dataset_galena.to_excel(caminho_salvar, index=False)

print("O arquivo dataset_galena foi salvo com sucesso!")
# Out:
# O arquivo dataset_galena foi salvo com sucesso!
